# %%
# importing libraries
import pandas as pd
import numpy as np 
import os

# %%
# path
path = r'/Users/michele/Desktop/CF/files/Module4/Instacart'

# %%
# importing files
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Original', 'products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared', 'orders_wrangled.csv'), index_col = False)

# %%
# check df_ords
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_days_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords.dtypes
# Out:
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_days_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# I have changed order_id and user_id to string in the previous exercise, but it doesn't show here

# %%
# change 'order_id' data type
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# change 'user_id' data type
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %% [markdown]
# ## Data Consistency Check for df_prods

# %%
# missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# df with only nan values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# 38187       38183          NaN        39             12    20.9
# 40444       40440          NaN       120             16    14.8

# %%
# chack the shape of df_prods
df_prods.shape
# Out:
# (49693, 5)

# %%
# create a new df without missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
# check df_prods_clean
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# deleting duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
# exporting df_prods_clean_no_dups
df_prods_clean_no_dups.to_csv(os.path.join(path, 'Data', 'Prepared', 'products_clean.csv'), index = False)

# %% [markdown]
# ## Data Consistency Check for df_ords

# %%
# preliminary check of df_ords
df_ords.describe()
# Out:
#          Unnamed: 0  order_number  order_days_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.710541e+06  1.715486e+01        2.776219e+00       1.345202e+01
# std    9.875817e+05  1.773316e+01        2.046829e+00       4.226088e+00
# min    0.000000e+00  1.000000e+00        0.000000e+00       0.000000e+00
# 25%    8.552705e+05  5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.710541e+06  1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.565812e+06  2.300000e+01        5.000000e+00       1.600000e+01
# max    3.421082e+06  1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %% [markdown]
# <b>order day of the week</b> spans form 0 to 6, so 0 stands for either Monday or Sunday.<br/>
# <b>order hour of day</b> from 00 to 23 so it's correct.<br/>
# <b>days since prior order</b> the count is lower compared to the other columns, so I suppose there are missing values in this column.

# %%
# checking mixed data types
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# no mix values (note for Ayoade, the original function in the exercise uses .applymap that has been deprecated, shoud this be addressed to someone?)

# %%
# missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# order_days_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
# create df with only nan values
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
# check df_ords_nan
df_ords_nan.head(50)
# Out:
#      Unnamed: 0 order_id user_id  order_number  order_days_of_week  \
# 0             0  2539329       1             1                   2
# 11           11  2168274       2             1                   2
# 26           26  1374495       3             1                   1
# 39           39  3343014       4             1                   6
# 45           45  2717275       5             1                   3
# 50           50  2086598       6             1                   5
# 54           54  2565571       7             1                   3
# 75           75   600894       8             1                   6
# 79           79   280530       9             1                   1
# 83           83  1224907      10             1                   2
# 89           89  2411567      11             1                   0
# 97           97  1483446      12             1                   1
# 103         103  2618231      13             1                   6
# 116         116  2906263      14             1                   2
# 130         130  2514324      15             1                   5
# 153         153  1273676      16             1                   2
# 160         160  1737705      17             1                   2
# 201         201  2780889      18             1                   6
# 208         208  1321974      19             1                   6
# 218         218   947722      20             1                   1
# 223         223  2625565      21             1                   1
# 257         257  2300537      22             1                   3
# 273         273  1792521      23             1                   5
# 278         278   611214      24             1                   3
# 297         297  2610576      25             1                   1
# 301         301  3229714      26             1                   2
# 314         314   361493      27             1                   3
# 396         396  1138968      28             1                   0
# 421         421  2064090      29             1                   5
# 440         440   375303      30             1                   1
# 449         449  2150649      31             1                   5
# 470         470   134879      32             1                   3
# 476         476  2906103      33             1                   3
# 480         480  2383661      34             1                   4
# 486         486  1269089      35             1                   5
# 496         496  3285797      36             1                   4
# 534         534   327827      37             1                   2
# 558         558  2873174      38             1                   0
# 571         571  2782479      39             1                   0
# 579         579  2570028      40             1                   0
# 589         589   252244      41             1                   6
# 595         595   940313      42             1                   2
# 612         612   606677      43             1                   1
# 624         624  1359969      44             1                   0
# 628         628   300892      45             1                   1
# 633         633  3345812      46             1                   1
# 653         653  2857489      47             1                   5
# 659         659  1035233      48             1                   6
# 670         670  1216869      49             1                   2
# 679         679  1363380      50             1                   3
#
#      order_hour_of_day  days_since_prior_order
# 0                    8                     NaN
# 11                  11                     NaN
# 26                  14                     NaN
# 39                  11                     NaN
# 45                  12                     NaN
# 50                  18                     NaN
# 54                   9                     NaN
# 75                   0                     NaN
# 79                  17                     NaN
# 83                  14                     NaN
# 89                  11                     NaN
# 97                  12                     NaN
# 103                 12                     NaN
# 116                 18                     NaN
# 130                 13                     NaN
# 153                  8                     NaN
# 160                 13                     NaN
# 201                 18                     NaN
# 208                 13                     NaN
# 218                 10                     NaN
# 223                 10                     NaN
# 257                  7                     NaN
# 273                 14                     NaN
# 278                 20                     NaN
# 297                 14                     NaN
# 301                 15                     NaN
# 314                  9                     NaN
# 396                 14                     NaN
# 421                 11                     NaN
# 440                 13                     NaN
# 449                 11                     NaN
# 470                 12                     NaN
# 476                 14                     NaN
# 480                 15                     NaN
# 486                 21                     NaN
# 496                 17                     NaN
# 534                 10                     NaN
# 558                 10                     NaN
# 571                 12                     NaN
# 579                  9                     NaN
# 589                 16                     NaN
# 595                 10                     NaN
# 612                 18                     NaN
# 624                  7                     NaN
# 628                 20                     NaN
# 633                 16                     NaN
# 653                 16                     NaN
# 659                 16                     NaN
# 670                  9                     NaN
# 679                  9                     NaN

# %% [markdown]
# They seem to be all first orders and this could be why there is no day since prior order. Will impute 0

# %%
df_ords['days_since_prior_order'] = df_ords['days_since_prior_order'].fillna(0)

# %%
df_ords.head(20)
# Out:
#     Unnamed: 0 order_id user_id  order_number  order_days_of_week  \
# 0            0  2539329       1             1                   2
# 1            1  2398795       1             2                   3
# 2            2   473747       1             3                   3
# 3            3  2254736       1             4                   4
# 4            4   431534       1             5                   4
# 5            5  3367565       1             6                   2
# 6            6   550135       1             7                   1
# 7            7  3108588       1             8                   1
# 8            8  2295261       1             9                   1
# 9            9  2550362       1            10                   4
# 10          10  1187899       1            11                   4
# 11          11  2168274       2             1                   2
# 12          12  1501582       2             2                   5
# 13          13  1901567       2             3                   1
# 14          14   738281       2             4                   2
# 15          15  1673511       2             5                   3
# 16          16  1199898       2             6                   2
# 17          17  3194192       2             7                   2
# 18          18   788338       2             8                   1
# 19          19  1718559       2             9                   2
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     0.0
# 1                   7                    15.0
# 2                  12                    21.0
# 3                   7                    29.0
# 4                  15                    28.0
# 5                   7                    19.0
# 6                   9                    20.0
# 7                  14                    14.0
# 8                  16                     0.0
# 9                   8                    30.0
# 10                  8                    14.0
# 11                 11                     0.0
# 12                 10                    10.0
# 13                 10                     3.0
# 14                 10                     8.0
# 15                 11                     8.0
# 16                  9                    13.0
# 17                 12                    14.0
# 18                 15                    27.0
# 19                  9                     8.0

# %%
# duplicates
df_dups_ord = df_ords[df_ords.duplicated()]

# %%
df_dups_ord
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, order_days_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# no duplicates in df_ords

# %%
# exporting df_ords
df_ords.to_csv(os.path.join(path, 'Data', 'Prepared', 'orders_clean.csv'), index = False)
